# %%
from cq_drawings import SimpleShaftSketchCQ
from ocp_vscode import show
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from cq_drawings import SimpleShaftSketchCQ
#       2 from ocp_vscode import show
#
# File ~/dgeometry/dgeometry/cases/cq_drawings.py:27
#      24 import IPython as IP
#      26 # Import cq from cq_solids which handles the path correctly
# ---> 27 from . import cq_solids as cqs
#      28 from .cq_solids import cq
#      30 from ..dgeometry import GeometryScene, GeometricalCase, plots_no
#
# ImportError: attempted relative import with no known parent package

# %%
sketch = SimpleShaftSketchCQ.from_random_data()
model = sketch.to_cq()
show(model, port=3939)

sketch.preview()
