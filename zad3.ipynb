# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

import matplotlib.pyplot as plt
from dgeometry import *
import dgeometry as dg

class zad3:
    pA = Point(3/2,7/2,7/2)('A')
    pB = Point(3,13,3/2)('B')
    pO = Point(10,10,10)('O')
    pE = Point(8,11,2)('E')
    pD = Point(3,15/2,8)('D')
    pF = Point(5/2,29/2,11)('F')
    p1 = Point(7,7.6,7.6)('1')
    p2 = Point(2.7,11,2)('2')
    p3 = Point(5.5,12,4.5)('3')
    p4 = Point(2.7,11,2)('4')
    ab = (pA^pB)(' ')
    ao = (pA^pO)(' ')
    bo = (pB^pO)(' ')
    df = (pD^pF)(' ')
    de = (pD^pE)(' ')
    ef = (pE^pF)(' ')
    l12 = (p1^p2)(' ')
    l34 = (p3^p4)(' ')
    P = Point(5.25,9.2,5.15)('P')
    Q = Point(6.15,12.25,5.1)('Q')
    def __init__(self):
        self.pA.plot_all()
        (self.pA@VPP).plot_vp()
        (self.pA@HPP).plot_hp()
        self.pB.plot_all()
        (self.pB@VPP).plot_vp()
        (self.pB@HPP).plot_hp()
        self.pO.plot_all()
        (self.pO@VPP).plot_vp()
        (self.pO@HPP).plot_hp()
        self.ab.plot_all()
        (self.ab@VPP).plot_vp()
        (self.ab@HPP).plot_hp()
        self.bo.plot_all()
        (self.bo@VPP).plot_vp()
        (self.bo@HPP).plot_hp()
        self.ao.plot_all()
        (self.ao@VPP).plot_vp()
        (self.ao@HPP).plot_hp()
        self.pE.plot_all()
        (self.pE@VPP).plot_vp()
        (self.pE@HPP).plot_hp()
        self.pD.plot_all()
        (self.pD@VPP).plot_vp()
        (self.pD@HPP).plot_hp()
        self.pF.plot_all()
        (self.pF@VPP).plot_vp()
        (self.pF@HPP).plot_hp()
        self.df.plot_all()
        (self.df@VPP).plot_vp()
        (self.df@HPP).plot_hp()
        self.de.plot_all()
        (self.de@VPP).plot_vp()
        (self.de@HPP).plot_hp()
        self.ef.plot_all()
        (self.ef@VPP).plot_vp()
        (self.ef@HPP).plot_hp()
    def plot12bis(self):
        (self.p1@VPP).plot_vp()
        (self.p2@VPP).plot_vp()
    def plot12prim(self):
        (self.p1@HPP).plot_hp()
        (self.p2@HPP).plot_hp()
    def con12(self):
        (self.l12@HPP).plot_hp()
    def showP(self):
        (self.P@VPP).plot_vp()
        (self.P@HPP).plot_hp()
        (self.P).plot_all()
    def plot34bis(self):
        (self.p3@VPP).plot_vp()
        (self.p4@VPP).plot_vp()
    def plot34prim(self):
        (self.p3@HPP).plot_hp()
        (self.p4@HPP).plot_hp()
    def con34(self):
        (self.l34@HPP).plot_hp()
    def showQ(self):
        (self.Q@VPP).plot_vp()
        (self.Q@HPP).plot_hp()
        (self.Q).plot_all()

SETUP3D = (20,60) # something like perspective ;)

GeometrySceneDG(init_3d=SETUP3D,figsize=(16,15) ) 

A = Point(3,4.5,1.5)('A')
B = Point(1.5,14,3)('B')
O = Point(8,10,9)('O')
D = Point(10,7.5,2)('D')
p1 = Point(3,13.2,4.5)('1')
p2 = Point(0,15,1.5)('2')
p3 = Point(5,6.65,4.4)('3')
p4 = Point(2.5,7.65,2)('4')
P = Point(6.2,6.15,5.4)('P')
zad = zad3()
zad.plot12bis()
zad.plot12prim()
zad.con12()
zad.showP()
zad.plot34bis()
zad.plot34prim()
zad.con34()
zad.showQ()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
